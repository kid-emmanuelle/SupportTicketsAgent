# %%
import pandas as pd

# %%
df = pd.read_csv("../data/ticket.csv")

# %%
# TOTAL LINES : 28587
# NAN :
#  "answer"  7
# tag_2          13
# tag_3         136
# tag_4        3058
# tag_5       14042
# tag_6       22713
# tag_7       26547
# tag_8       28022


df.isna().sum()
# Out:
# subject      3838
# body            0
# answer          7
# type            0
# queue           0
# priority        0
# language        0
# version         0
# tag_1           0
# tag_2          13
# tag_3         136
# tag_4        3058
# tag_5       14042
# tag_6       22713
# tag_7       26547
# tag_8       28022
# dtype: int64

# %%
# column "body" - query d'utilisateur
# columns "answer - reponse de support
# column "type" : ['Incident', 'Request', 'Problem', 'Change']
# column "queue" : ['Technical Support', 'Returns and Exchanges',
#    'Billing and Payments', 'Sales and Pre-Sales',
#    'Service Outages and Maintenance', 'Product Support', 'IT Support',
#    'Customer Service', 'Human Resources', 'General Inquiry']
# column "priority" : ['high', 'medium', 'low']
# column "language":['de', 'en']
# column "version":[ 51,  52, 400] - ?
# column "tags" : 1256 valeurs uniques
tags = set()
for i in range(1, 9):
    x = set(df[f"tag_{i}"].unique())
    tags = tags.union(x)

# %%
len(tags)
# Out:
# 1256
